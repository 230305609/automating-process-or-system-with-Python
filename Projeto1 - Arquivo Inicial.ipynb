# %% [markdown]
# # Automação de Sistemas e Processos com Python
#
# ### Desafio:
#
# Para controle de custos, todos os dias, seu chefe pede um relatório com todas as compras de mercadorias da empresa.
# O seu trabalho, como analista, é enviar um e-mail para ele, assim que começar a trabalhar, com o total gasto, a quantidade de produtos compradas e o preço médio dos produtos.
#
# E-mail do seu chefe: para o nosso exercício, coloque um e-mail seu como sendo o e-mail do seu chefe<br>
# Link de acesso ao sistema da empresa: https://pages.hashtagtreinamentos.com/aula1-intensivao-sistema
#
# Para resolver isso, vamos usar o pyautogui, uma biblioteca de automação de comandos do mouse e do teclado

# %%
import pyautogui
import time

#pyautogui.click -> clicar com o mouse
#pyautogui.write -> escrever um texto
#pyautogui.press -> apertar uma tecla
#pyautogui.hotkey -> apertar uma combinação de teclas 

pyautogui.PAUSE = 1

#Passo 1: Acessar o sistema da empresa
pyautogui.hotkey("ctrl", "t")
pyautogui.write("https://pages.hashtagtreinamentos.com/aula1-intensivao-sistema") 
pyautogui.press("enter")

time.sleep(5)

#Passo 2: Fazer login no sistema

pyautogui.click(x=1667, y=32)
pyautogui.write("meu login")

pyautogui.click(x=912, y=529)
pyautogui.write("minha senha")

pyautogui.click(x=1036, y=609)

time.sleep(5)

#Passo 3: Baixar a base de dados
pyautogui.click(x=504, y=440)
pyautogui.click(x=872, y=212)
pyautogui.click(x=990, y=628)

time.sleep(5)

# %%
#Passo 4: Calcular os indicadores
from sys import displayhook
import pandas as pd
# as e pra chamar o pandas de pd, pra simplificar 

#importar a base de dados  
#sep = sep e o separador que voce escolhe, que foi o ;
# r = ssignifica que voce quer o texto cru, como ele e 
tabela = pd.read_csv(r"C:\Users\victor\Downloads\Estudos\Intensivão de Python\drive-download-20230515T224301Z-001\Compras.csv", sep=";")
displayhook(tabela)

#calculo dos indicadores
#.sum (igual a soma) 
#total gasto -> somar a coluna valor final
total_gasto = tabela["ValorFinal"].sum()

#quantidade -> somar a coluna quantidade
quantidade = tabela["Quantidade"].sum()

#preco medio -> total gasto / quantidade
preco_medio = total_gasto / quantidade

print(total_gasto)
print(quantidade)
print(preco_medio)
# Out:
#       CódigoCompra        Data               Fornecedor
# 0            65014  01/12/2023   Fabrica Hashtag Brasil  \
# 1            65014  01/12/2023   Fabrica Hashtag Brasil
# 2            65016  01/12/2023   Fabrica Doidona Brasil
# 3            65016  01/12/2023   Fabrica Doidona Brasil
# 4            65017  01/12/2023  Original Fábrica Brasil
# ...            ...         ...                      ...
# 4538         69996  26/12/2023        Revenda Argentina
# 4539         69996  26/12/2023        Revenda Argentina
# 4540         69996  26/12/2023        Revenda Argentina
# 4541         69997  26/12/2023   Fabrica Doidona Mexico
# 4542         69997  26/12/2023   Fabrica Doidona Mexico
#
#                             Produto  Quantidade  ValorUnitário  ValorFinal
# 0              Óleo Motor - Linha A           5         259.00     1295.00
# 1           Kit Embreagem - Linha A           1         380.00      380.00
# ...

# %%
import pyperclip
#Passo 5: Enviar o email para a diretoria/para o chefe

# entrar no meu email
pyautogui.hotkey("ctrl", "t")
pyautogui.write("https://outlook.live.com/mail/0/") 
pyautogui.press("enter")

time.sleep(5)

# clicar em escrever
pyautogui.click(x=233, y=168)

# preencher o email
pyautogui.write("vitor_TFTEC@hotmail.com")
pyautogui.press("tab") # selecionar o email

pyautogui.press("tab") #passar pro proximo campo
pyperclip.copy("Relatorio de compras")
pyautogui.hotkey("ctrl", "v")
# pyperclip pra copiar o texto criado, o ctrl + v no pyautogui pra ele colar esse texto copiado

pyautogui.press("tab") #passar pro proximo campo
# : = significa que vocer quer formatar
#.2f = duas casas decimais
#, = separador de bilhar
texto = f'''
Preazados,

Segue o relatorio de compras

Total Gasto: R${total_gasto:,.2f}
Quantidade de Produtos: {quantidade:,}
Preço Medio: R${preco_medio:,.2f}

Qualquer duvida e so falar.
Att.,
VAQB
''' 
pyperclip.copy(texto)
pyautogui.write("ctrl", "v")
# pyperclip pra copiar o texto criado, o ctrl + v no pyautogui pra ele colar esse texto copiado

# enviar
pyautogui.hotkey("ctrl", "enter")

# %%
#Descobrir a medida das posições
time.sleep(5)
print(pyautogui.position())
# Out:
# Point(x=233, y=168)

# %%
# !pip install pyautogui

# !pip install pandas

# !pip install openpyxl

# !pip install numpy
# Out:
# ...
#                                               0.0/10.6 MB ? eta -:--:--
#      ---                                      0.8/10.6 MB 17.6 MB/s eta 0:00:01
#      ------                                   1.6/10.6 MB 17.6 MB/s eta 0:00:01
#      -------------------                      5.0/10.6 MB 36.0 MB/s eta 0:00:01
#      ----------------------------------       9.2/10.6 MB 49.3 MB/s eta 0:00:01
#      --------------------------------------  10.6/10.6 MB 54.7 MB/s eta 0:00:01
#      --------------------------------------- 10.6/10.6 MB 43.7 MB/s eta 0:00:00
# ...
#                                               0.0/502.3 kB ? eta -:--:--
#      ------------------------------------- 502.3/502.3 kB 30.8 MB/s eta 0:00:00
# ...
#   Using cached tzdata-2023.3-py2.py3-none-any.whl (341 kB)
# ...
#                                               0.0/14.8 MB ? eta -:--:--
#      -----                                    1.9/14.8 MB 41.2 MB/s eta 0:00:01
# ...
